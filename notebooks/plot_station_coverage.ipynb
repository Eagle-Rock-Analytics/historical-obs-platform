# %% [markdown]
# # Plot cleaned station coverage
# Create figures of station coverage for cleaned stations on a map of WECC. Also enables figure generation by individual variables.

# %%
import matplotlib.pylab as plt

from figure_utils import *

#! To do: fix legends in plots

# %% [markdown]
# For more information on all figure generating utilities, type: `help(single_var_map)`

# %%
# All available variables
vars_all = [
    "tas",
    "tdps",
    "tdps_derived",
    "ps",
    "psl",
    "ps_altimeter",
    "pr",
    "pr_5min",
    "pr_1h",
    "pr_24h",
    "pr_localmid",
    "hurs",
    "sfcwind",
    "sfcwind_dir",
    "rsds",
]

# %%
# Generate a single variable map, with options to save to AWS or in local directory
single_var_map(var="tas", save_to_aws=False, save_local=False)

# %%
# Generate a single variable map for all variables, with options to save to AWS or in local directory
for var in vars_all:
    single_var_map(var=var)

# %%
# Generate a combined map with all variables, with options to save to AWS or in local directory
plot_combined_station_vars(
    vars_all, 
    save_to_aws=False, 
    save_local=False
)

# %%
# Generate a combined map with specific user-defined variables, with options to save ot AWS or in local directory
plot_combined_station_vars(
    ["sfcwind", "rsds"], 
    ncols=2,
    save_to_aws=False, 
    save_local=False
    )
